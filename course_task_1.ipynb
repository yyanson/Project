# %% [markdown]
# ### апрель 2022 Модель№1 (без лишнего)

# %% [markdown]
# ### Подключение библиотек и скриптов

# %%
import numpy as np
import pandas as pd
import pickle
import os

from scipy.spatial.distance import cdist
from mpl_toolkits.mplot3d.axes3d import Axes3D

from sklearn.preprocessing import StandardScaler, RobustScaler

# Кластеризация
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering

from sklearn.neighbors import KNeighborsClassifier

# Понижения размерности
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score as r2, mean_absolute_error as mae, mean_squared_error as mse

from sklearn.ensemble import GradientBoostingRegressor

import warnings
warnings.filterwarnings('ignore')

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def evaluate_preds(train_true_values, train_pred_values, test_true_values, test_pred_values):
    print("Train R2:\t" + str(round(r2(train_true_values, train_pred_values), 3)))
    print("Test R2:\t" + str(round(r2(test_true_values, test_pred_values), 3)))
    
    plt.figure(figsize=(18,10))
    
    plt.subplot(121)
    sns.scatterplot(x=train_pred_values, y=train_true_values)
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('Train sample prediction')
    
    plt.subplot(122)
    sns.scatterplot(x=test_pred_values, y=test_true_values)
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('Test sample prediction')

    plt.show()

# %%
os.chdir('C:\\Users\\yyans\\OneDrive\\Desktop\\!_GB\\4_Python для Data Science\\Course_work')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\yyans\\OneDrive\\Desktop\\!_GB\\4_Python для Data Science\\Course_work'

# %%
train_df = pd.read_csv('train.csv')
train_df.head()
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0  11809          27    3.0  115.027311         NaN           10.0      4
# 1   3013          22    1.0   39.832524   23.169223            8.0      7
# 2   8215           1    3.0   78.342215   47.671972           10.0      2
# 3   2352           1    1.0   40.409907         NaN            1.0     10
# 4  13866          94    2.0   64.285067   38.562517            9.0     16
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        10.0       2014   0.075424         B         B        11      3097
# 1         8.0       1966   0.118537         B         B        30      6207
# 2        17.0       1988   0.025609         B         B        33      5261
# 3        22.0       1977   0.007122         B         B         1       264
# 4        16.0       1972   0.282798         B         B        33      8667
#
# ...

# %% [markdown]
# Есть категориальные перменные.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %% [markdown]
# Есть NaN в LifeSquare и Healthcare_1.
# Категориальные переменные в Ecology_2, Ecology_3, Shops_2

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#      Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  4567          44    1.0  36.847630   19.094182            5.0      5
# 1  5925          62    1.0  42.493907   42.568133           10.0      7
# 2   960          27    2.0  59.463678         NaN            9.0     19
# 3  3848          23    3.0  49.646030   33.893825            6.0      2
# 4   746          74    1.0  53.837056         NaN            1.0      8
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1970   0.036122         B         B        24      4378
# 1        17.0       2017   0.072158         B         B         2       629
# 2        19.0       1977   0.211401         B         B         9      1892
# 3         2.0       1965   0.014073         B         B         2       475
# 4        17.0       1977   0.309479         B         B        35      7715
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %%
test_df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     3959 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   2623 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
# ...

# %% [markdown]
# Переменная 'Shops_2': пусть А = 0, В = 10

# %%
train_df.loc[train_df['Shops_2'] == 'A', 'Shops_2'] = 0
train_df.loc[train_df['Shops_2'] == 'B', 'Shops_2'] = 10
test_df.loc[test_df['Shops_2'] == 'A', 'Shops_2'] = 0
test_df.loc[test_df['Shops_2'] == 'B', 'Shops_2'] = 10

# %% [markdown]
# Переведем Shops_2 в int

# %%
train_df['Shops_2'] = train_df['Shops_2'].astype(int)
test_df['Shops_2'] = test_df['Shops_2'].astype(int)

# %% [markdown]
# Удалим 'Id', 'Ecology_2' и 'Ecology_3'

# %%
train_df.drop(['Id', 'Ecology_2','Ecology_3'], axis=1, inplace=True)
test_df.drop(['Id', 'Ecology_2','Ecology_3'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#    DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0          27    3.0  115.027311         NaN           10.0      4
# 1          22    1.0   39.832524   23.169223            8.0      7
# 2           1    3.0   78.342215   47.671972           10.0      2
# 3           1    1.0   40.409907         NaN            1.0     10
# 4          94    2.0   64.285067   38.562517            9.0     16
#
#    HouseFloor  HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# 0        10.0       2014   0.075424        11      3097         0
# 1         8.0       1966   0.118537        30      6207         1
# 2        17.0       1988   0.025609        33      5261         0
# 3        22.0       1977   0.007122         1       264         0
# 4        16.0       1972   0.282798        33      8667         2
#
#    Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price
# 0           NaN            0        0       10  305018.871089
# ...

# %% [markdown]
# Удалим LifeSquare

# %%
train_df.drop(['LifeSquare'], axis=1, inplace=True)
test_df.drop(['LifeSquare'], axis=1, inplace=True)

# %% [markdown]
# Не будем заполнять NaN в 'Healthcare_1', тоже удалим эти данные

# %%
train_df.drop(['Healthcare_1'], axis=1, inplace=True)
test_df.drop(['Healthcare_1'], axis=1, inplace=True)

# %% [markdown]
# Приступим к анализу даных. Выделяем целевую переменную.

# %%
target_name = 'Price'

# %%
X = train_df.drop(columns=target_name)
y = train_df[target_name]

# %%
X.head()
# Out:
#    DistrictId  Rooms      Square  KitchenSquare  Floor  HouseFloor  HouseYear  \
# 0          27    3.0  115.027311           10.0      4        10.0       2014
# 1          22    1.0   39.832524            8.0      7         8.0       1966
# 2           1    3.0   78.342215           10.0      2        17.0       1988
# 3           1    1.0   40.409907            1.0     10        22.0       1977
# 4          94    2.0   64.285067            9.0     16        16.0       1972
#
#    Ecology_1  Social_1  Social_2  Social_3  Helthcare_2  Shops_1  Shops_2
# 0   0.075424        11      3097         0            0        0       10
# 1   0.118537        30      6207         1            1        0       10
# 2   0.025609        33      5261         0            3        1       10
# 3   0.007122         1       264         0            0        1       10
# 4   0.282798        33      8667         2            0        6       10

# %%
y.head()
# Out:
# 0    305018.871089
# 1    177734.553407
# 2    282078.720850
# 3    168106.007630
# 4    343995.102962
# Name: Price, dtype: float64

# %% [markdown]
# Делим тренировачные данные на выборку для обучения и выборку для валидации

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=21)

# %% [markdown]
# Обучаем модель на RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=21, criterion='mse')
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=21)

# %% [markdown]
# Очениваем результат

# %%
y_train_preds = rf_model.predict(X_train)
y_test_preds = rf_model.predict(X_valid)

evaluate_preds(y_train, y_train_preds, y_valid, y_test_preds)
# Out:
# Train R2:	0.959
# Test R2:	0.737

# %% [markdown]
# Предсказываем на тестовой выборке

# %%
y_test = rf_model.predict(test_df)

# %%
y_test
# Out:
# array([161546.07790429, 121771.12843961, 140740.00949469, ...,
#        145834.94900129, 187440.14091723, 280674.25151629])

# %%
submit = pd.read_csv('sample_submission.csv')

# %%
submit['Price'] = y_test
submit.head()
# Out:
#      Id          Price
# 0  4567  161546.077904
# 1  5925  121771.128440
# 2   960  140740.009495
# 3  3848  119069.421145
# 4   746  210723.058841

# %%
submit.to_csv('rf_submit.csv', index=False)
